# %% [markdown]
# <a href="https://colab.research.google.com/github/crystalclcm/JobPostings/blob/main/untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load all three CSVs
old = pd.read_csv('/content/IE_DS_2015_to_2019.csv')
new = pd.read_csv('/content/DS_2021_2023.csv')
eu_old = pd.read_csv('/content/EU_DS_2015_to_2019.csv')  # Upload this file first

# Normalize column names
old.columns = [c.strip() for c in old.columns]
new.columns = [c.strip() for c in new.columns]
eu_old.columns = [c.strip() for c in eu_old.columns]

# Map Ireland name to IE
old['geo'] = old['geo'].replace({'Ireland': 'IE'})
eu_old['geo'] = eu_old['geo'].replace({'European Union': 'EU27_2020', 'EU': 'EU27_2020'})

# Keep only needed columns
old = old[['TIME_PERIOD', 'geo', 'OBS_VALUE']].dropna()
new = new[['TIME_PERIOD', 'geo', 'OBS_VALUE']].dropna()
eu_old = eu_old[['TIME_PERIOD', 'geo', 'OBS_VALUE']].dropna()

# Convert year to int
old['TIME_PERIOD'] = old['TIME_PERIOD'].astype(int)
new['TIME_PERIOD'] = new['TIME_PERIOD'].astype(int)
eu_old['TIME_PERIOD'] = eu_old['TIME_PERIOD'].astype(int)

# Combine all datasets
combined = pd.concat([old, new, eu_old])

# Filter for IE and EU aggregate
combined = combined[combined['geo'].isin(['IE', 'EU27_2020'])]

# Pivot for visualization
pivot = combined.pivot_table(index='TIME_PERIOD', columns='geo', values='OBS_VALUE')
pivot.sort_index(inplace=True)

# %%
# --- Visualization: Eurostat Trend (Ireland vs EU) ---
import plotly.express as px

fig = px.line(
    pivot.reset_index(),
    x='TIME_PERIOD',
    y=pivot.columns,
    markers=True,
    title='Digital Skills Trend: Ireland vs EU (2015–2023)',
    labels={'value':'% Digital Skills','TIME_PERIOD':'Year'},
    color_discrete_map={'IE':'blue','EU27_2020':'green'}
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f811e3dd-669e-4d5f-9ae8-e45f925c549f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f811e3dd-669e-4d5f-9ae8-e45f925c549f")) {                    Plotly.newPlot(                        "f811e3dd-669e-4d5f-9ae8-e45f925c549f",                        [{"hovertemplate":"variable=EU27_2020\u003cbr\u003eYear=%{x}\u003cbr\u003e% Digital Skills=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"EU27_2020","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"EU27_2020","orientation":"v","showlegend":true,"x":[2015,2016,2017,2019,2021,2023],"xaxis":"x","y":[26.306,26.906,27.454,28.406,53.93333333333334,55.57],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=IE\u003cbr\u003eYear=%{x}\u003cbr\u003e% Digital Skills=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"IE","line":{"color":"blue","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"IE","orientation":"v","showlegend":true,"x":[2015,2016,2017,2019,2021,2023],"xaxis":"x","y":[28.146666666666665,28.424999999999997,29.418333333333333,32.85,70.49666666666667,72.93],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpa ...

# %%
fig_area = px.area(
    pivot.reset_index(),
    x='TIME_PERIOD',
    y=pivot.columns,
    title='Growth in Digital Skills: Ireland vs EU (2015–2023)',
    labels={'value':'% Digital Skills','TIME_PERIOD':'Year'},
    color_discrete_map={'IE':'blue','EU27_2020':'green'}
)

# %%
change = pivot.iloc[-1] - pivot.iloc[0]
change_df = change.reset_index()
change_df.columns = ['Region','Change']

fig_change = px.bar(
    change_df,
    x='Region',
    y='Change',
    title='Percentage Point Change in Digital Skills (2015–2023)',
    labels={'Change':'Change in % points'}
)
fig_change.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bd85f948-f695-4635-8859-4daca7913b8a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd85f948-f695-4635-8859-4daca7913b8a")) {                    Plotly.newPlot(                        "bd85f948-f695-4635-8859-4daca7913b8a",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eChange in % points=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["EU27_2020","IE"],"xaxis":"x","y":[29.264,44.783333333333346],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"t ...

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# --- Eurostat pivot table (already created in your previous code) ---
# pivot contains TIME_PERIOD as index and columns ['IE','EU27_2020']

# --- Kaggle job posting snapshot ---
skill_df = pd.DataFrame({
    'Skill': ['Cloud', 'SQL', 'Python', 'Statistics', 'AI', 'Java', 'Machine Learning', 'Data Science', 'Big Data'],
    'Percentage': [7.4, 4.2, 3.6, 3.1, 2.9, 2.2, 1.8, 1.3, 1.2]
})

# Sort skills for better visualization
sorted_skills = skill_df.sort_values('Percentage', ascending=True)

# Create dashboard
fig_dashboard = make_subplots(
    rows=1, cols=2,
    subplot_titles=('Eurostat Digital Skills Trend (IE vs EU)', 'Job Posting Skill Demand (2023-2024)'),
    column_widths=[0.55, 0.45]
)

# Left: Eurostat trend
fig_dashboard.add_trace(go.Scatter(x=pivot.index, y=pivot['IE'], mode='lines+markers', name='Ireland'), row=1, col=1)
if 'EU27_2020' in pivot.columns:
    fig_dashboard.add_trace(go.Scatter(x=pivot.index, y=pivot['EU27_2020'], mode='lines+markers', name='EU'), row=1, col=1)
fig_dashboard.update_xaxes(title_text='Year', row=1, col=1)
fig_dashboard.update_yaxes(title_text='% Digital Skills', row=1, col=1)

# Right: Kaggle snapshot
fig_dashboard.add_trace(go.Bar(x=sorted_skills['Percentage'], y=sorted_skills['Skill'], orientation='h', name='Skills'), row=1, col=2)
fig_dashboard.update_xaxes(title_text='Share of postings (%)', row=1, col=2)

fig_dashboard.update_layout(
    title_text='Digital Skills vs Industry Demand',
    height=600,
    annotations=[dict(text='Note: Kaggle dataset represents 2023-2024 snapshot', x=0.75, y=-0.15, xref='paper', yref='paper', showarrow=False)]
)

fig_dashboard.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1dfc0ecc-fbfb-43fb-9d1d-307eacbfbce1" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1dfc0ecc-fbfb-43fb-9d1d-307eacbfbce1")) {                    Plotly.newPlot(                        "1dfc0ecc-fbfb-43fb-9d1d-307eacbfbce1",                        [{"mode":"lines+markers","name":"Ireland","x":[2015,2016,2017,2019,2021,2023],"y":[28.146666666666665,28.424999999999997,29.418333333333333,32.85,70.49666666666667,72.93],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"lines+markers","name":"EU","x":[2015,2016,2017,2019,2021,2023],"y":[26.306,26.906,27.454,28.406,53.93333333333334,55.57],"type":"scatter","xaxis":"x","yaxis":"y"},{"name":"Skills","orientation":"h","x":[1.2,1.3,1.8,2.2,2.9,3.1,3.6,4.2,7.4],"y":["Big Data","Data Science","Machine Learning","Java","AI","Statistics","Python","SQL","Cloud"],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y" ...

# %%
import pandas as pd
import plotly.express as px

# %%
old = pd.read_csv('/content/IE_DS_2015_to_2019.csv')
new = pd.read_csv('/content/DS_2021_2023.csv')

# %%
old.columns = [c.strip() for c in old.columns]
new.columns = [c.strip() for c in new.columns]

# %%
old['geo'] = old['geo'].replace({'Ireland': 'IE'})

# %%
old = old[['TIME_PERIOD', 'geo', 'OBS_VALUE']].dropna()
new = new[['TIME_PERIOD', 'geo', 'OBS_VALUE']].dropna()

# %%
old['TIME_PERIOD'] = old['TIME_PERIOD'].astype(int)
new['TIME_PERIOD'] = new['TIME_PERIOD'].astype(int)

# %%
eu_codes = ['EU27_2020','EU28','EU27','EU']
eu_old = next((code for code in eu_codes if code in old['geo'].unique()), None)
eu_new = next((code for code in eu_codes if code in new['geo'].unique()), None)

old_filtered = old[old['geo'].isin(['IE'] + ([eu_old] if eu_old else []))]
new_filtered = new[new['geo'].isin(['IE'] + ([eu_new] if eu_new else []))]

# %%
combined = pd.concat([old_filtered, new_filtered])
pivot = combined.pivot_table(index='TIME_PERIOD', columns='geo', values='OBS_VALUE')
pivot.sort_index(inplace=True)

# %%
fig1 = px.line(pivot.reset_index(), x='TIME_PERIOD', y=pivot.columns,
               markers=True,
               title='Digital Skills Trend: Ireland vs EU',
               labels={'value':'% Digital Skills','TIME_PERIOD':'Year'},
               color_discrete_map={'IE':'blue','EU27_2020':'green'})
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5b34636b-6a56-4b0c-b677-ac992bb658bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b34636b-6a56-4b0c-b677-ac992bb658bf")) {                    Plotly.newPlot(                        "5b34636b-6a56-4b0c-b677-ac992bb658bf",                        [{"hovertemplate":"variable=EU27_2020\u003cbr\u003eYear=%{x}\u003cbr\u003e% Digital Skills=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"EU27_2020","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"EU27_2020","orientation":"v","showlegend":true,"x":[2015,2016,2017,2019,2021,2023],"xaxis":"x","y":[null,null,null,null,53.93333333333334,55.57],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=IE\u003cbr\u003eYear=%{x}\u003cbr\u003e% Digital Skills=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"IE","line":{"color":"blue","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"IE","orientation":"v","showlegend":true,"x":[2015,2016,2017,2019,2021,2023],"xaxis":"x","y":[44.38,44.19,47.64,53.38,70.49666666666667,72.93],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidit ...

# %%
from google.colab import files

# %%
# Load job postings dataset
job_df = pd.read_csv('/content/postings.csv')  # Replace with actual filename

# Combine skills_desc and description
job_df['combined_text'] = job_df['skills_desc'].fillna('') + ' ' + job_df['description'].fillna('')

# Expanded skill list
skills_to_track = ['AI', 'Machine Learning', 'Data Science', 'Statistics', 'Python', 'Java', 'SQL', 'Cloud', 'Big Data']

# Count occurrences across entire dataset
skill_counts = {}
for skill in skills_to_track:
    skill_counts[skill] = job_df['combined_text'].str.contains(skill, case=False, na=False).sum()

# Convert to DataFrame
skill_df = pd.DataFrame(list(skill_counts.items()), columns=['Skill', 'Frequency'])
print(skill_df)

# Visualize
fig2 = px.bar(skill_df, x='Skill', y='Frequency', color='Skill',
             title='Job Posting Skill Demand (All Data)')
fig2.show()
# Out:
#               Skill  Frequency
# 0                AI     117270
# 1  Machine Learning       1726
# 2      Data Science       1404
# 3        Statistics       2078
# 4            Python       4905
# 5              Java       4102
# 6               SQL       6028
# 7             Cloud       7850
# 8          Big Data        715
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="99e71512-140a-47e0-ac5f-8e961f049504" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99e71512-140a-47e0-ac5f-8e961f049504")) {                    Plotly.newPlot(                        "99e71512-140a-47e0-ac5f-8e961f049504",                        [{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AI","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"AI","offsetgroup":"AI","orientation":"v","showlegend":true,"textposition":"auto","x":["AI"],"xaxis":"x","y":[117270],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Machine Learning","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Machine Learning","offsetgroup":"Machine Learning","orientation":"v","showlegend":true,"textposition":"auto","x":["Machine Learning"],"xaxis":"x","y":[1726],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Data Science","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Data Science","offsetgroup":"Data Science","orientation":"v","showlegend":true,"textposition":"auto","x":["Data Science"],"xaxis":"x","y":[1404],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Statistics","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Statistics","offsetgroup":"Statistics","orientation":"v","showlegend":true,"textposition":"auto","x":["Statistics"],"xaxis":"x","y":[2078],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Python","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Python","offsetgroup":"Python","orientation":"v","showlegend":true,"textposition":"auto","x":["Python"],"xaxis":"x","y":[4905],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Java","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Java","offsetgroup":"Java","orientation":"v","showlegend":true,"textposition":"auto","x":["Java"],"xaxis":"x","y":[4102],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SQL","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"SQL","offsetgroup":"SQL","orientation":"v","showlegend":true,"textposition":"auto","x":["SQL"],"xaxis":"x","y":[6028],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cloud","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Cloud","offsetgroup":"Cloud","orientation":"v","showlegend":true,"textposition":"auto","x":["Cloud"],"xaxis":"x","y":[7850],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Big Data","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Big Data","offsetgroup":"Big Data","orientation":"v","showlegend":true,"textposition":"auto","x":["Big Data"],"xaxis":"x","y":[715],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887 ...

# %%
# Normalize to percentage
total = skill_df['Frequency'].sum()
skill_df['Percentage'] = (skill_df['Frequency'] / total) * 100

# Visualize normalized data
fig_norm = px.bar(skill_df, x='Skill', y='Percentage', color='Skill',
                  title='Job Posting Skill Demand (Normalized %)')
fig_norm.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c51434e9-afb1-44f5-a169-0c3754780ca6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c51434e9-afb1-44f5-a169-0c3754780ca6")) {                    Plotly.newPlot(                        "c51434e9-afb1-44f5-a169-0c3754780ca6",                        [{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003ePercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AI","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"AI","offsetgroup":"AI","orientation":"v","showlegend":true,"textposition":"auto","x":["AI"],"xaxis":"x","y":[80.27902901189775],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003ePercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Machine Learning","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Machine Learning","offsetgroup":"Machine Learning","orientation":"v","showlegend":true,"textposition":"auto","x":["Machine Learning"],"xaxis":"x","y":[1.1815605361519188],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003ePercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Data Science","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Data Science","offsetgroup":"Data Science","orientation":"v","showlegend":true,"textposition":"auto","x":["Data Science"],"xaxis":"x","y":[0.9611303550158135],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003ePercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Statistics","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Statistics","offsetgroup":"Statistics","orientation":"v","showlegend":true,"textposition":"auto","x":["Statistics"],"xaxis":"x","y":[1.422527690685798],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003ePercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Python","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Python","offsetgroup":"Python","orientation":"v","showlegend":true,"textposition":"auto","x":["Python"],"xaxis":"x","y":[3.357795150536015],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003ePercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Java","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Java","offsetgroup":"Java","orientation":"v","showlegend":true,"textposition":"auto","x":["Java"],"xaxis":"x","y":[2.8080888292556034],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003ePercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SQL","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"SQL","offsetgroup":"SQL","orientation":"v","showlegend":true,"textposition":"auto","x":["SQL"],"xaxis":"x","y":[4.126562521392681],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003ePercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cloud","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Cloud","offsetgroup":"Cloud","orientation":"v","showlegend":true,"textposition":"auto","x":["Cloud"],"xaxis":"x","y":[5.373841372417475],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003ePercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Big Data","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Big Data","offsetgroup":"Big Data","orientation":"v","showlegend":true,"textposition":"auto","x":["Big Data"],"xaxis":"x","y":[0.48946453264694206],"yaxis":"y","type":"bar"}],                        {"template ...

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# Create subplots
fig = make_subplots(rows=1, cols=2, subplot_titles=('Eurostat Digital Skills Trend', 'Job Posting Skill Demand'))

# Add Eurostat line chart
for col in pivot.columns:
    fig.add_trace(go.Scatter(x=pivot.index, y=pivot[col], mode='lines+markers', name=col), row=1, col=1)

# Add Job Posting bar chart
fig.add_trace(go.Bar(x=skill_df['Skill'], y=skill_df['Frequency'], name='Skills'), row=1, col=2)

fig.update_layout(title_text='Digital Skills vs Industry Demand', showlegend=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b2fe52eb-8f3c-43e2-ae41-c8fb76c22924" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2fe52eb-8f3c-43e2-ae41-c8fb76c22924")) {                    Plotly.newPlot(                        "b2fe52eb-8f3c-43e2-ae41-c8fb76c22924",                        [{"mode":"lines+markers","name":"EU27_2020","x":[2015,2016,2017,2019,2021,2023],"y":[null,null,null,null,53.93333333333334,55.57],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"lines+markers","name":"IE","x":[2015,2016,2017,2019,2021,2023],"y":[44.38,44.19,47.64,53.38,70.49666666666667,72.93],"type":"scatter","xaxis":"x","yaxis":"y"},{"name":"Skills","x":["AI","Machine Learning","Data Science","Statistics","Python","Java","SQL","Cloud","Big Data"],"y":[117270,1726,1404,2078,4905,4102,6028,7850,715],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5EC ...

# %%
import pandas as pd
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# --- Combine text fields & normalize ---
job_df['combined_text'] = (
    job_df['skills_desc'].fillna('') + ' ' + job_df['description'].fillna('')
).str.lower()

# --- Regex patterns with word boundaries & synonyms ---
patterns = {
    'AI': r'\b(ai|artificial intelligence)\b',
    'Machine Learning': r'\b(machine learning|ml)\b',
    'Data Science': r'\b(data science|data scientist)\b',
    'Statistics': r'\b(statistics?|statistical)\b',
    'Python': r'\bpython\b',
    'Java': r'\bjava\b',
    'SQL': r'\b(sql|structured query language)\b',
    'Cloud': r'\b(cloud|aws|amazon web services|azure|microsoft azure|gcp|google cloud)\b',
    'Big Data': r'\b(big data|hadoop|spark)\b'
}

def mentions(series, pattern):
    return series.str.contains(pattern, regex=True, na=False)

total_postings = len(job_df)
freq = {skill: mentions(job_df['combined_text'], pat).sum() for skill, pat in patterns.items()}

skill_df = (
    pd.DataFrame({'Skill': list(freq.keys()), 'Frequency': list(freq.values())})
      .sort_values('Frequency', ascending=False)
      .reset_index(drop=True)
)
skill_df['Percentage'] = (skill_df['Frequency'] / total_postings) * 100

print("Total postings:", total_postings)
print(skill_df)
# Out:
# /tmp/ipython-input-2113746919.py:25: UserWarning:
#
# This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
# Total postings: 123849
#               Skill  Frequency  Percentage
# 0             Cloud       9051    7.308093
# 1               SQL       5194    4.193817
# 2            Python       4655    3.758609
# 3        Statistics       3959    3.196635
# 4                AI       3700    2.987509
# 5              Java       2672    2.157466
# 6  Machine Learning       2121    1.712569
# 7      Data Science       1390    1.122334
# 8          Big Data       1376    1.111030

# %%
# --- Raw counts (optionally log scale) ---
fig_counts = px.bar(
    skill_df, x='Skill', y='Frequency', color='Skill',
    title='Job Posting Skill Demand (Counts)'
)
# Uncomment the next line if AI dwarfs the chart and you want clearer separation:
# fig_counts.update_yaxes(type='log')
fig_counts.show()

# --- Normalized percentages (recommended for the dashboard) ---
fig_pct = px.bar(
    skill_df, x='Skill', y='Percentage', color='Skill',
    title='Job Posting Skill Demand (Normalized %)',
    text=skill_df['Percentage'].round(2).astype(str) + '%'
)
fig_pct.update_traces(textposition='outside')
fig_pct.update_layout(yaxis_title='Share of postings (%)')
fig_pct.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fa3504a3-a136-43a3-9846-37df85c17aba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa3504a3-a136-43a3-9846-37df85c17aba")) {                    Plotly.newPlot(                        "fa3504a3-a136-43a3-9846-37df85c17aba",                        [{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cloud","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Cloud","offsetgroup":"Cloud","orientation":"v","showlegend":true,"textposition":"auto","x":["Cloud"],"xaxis":"x","y":[9051],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SQL","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"SQL","offsetgroup":"SQL","orientation":"v","showlegend":true,"textposition":"auto","x":["SQL"],"xaxis":"x","y":[5194],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Python","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Python","offsetgroup":"Python","orientation":"v","showlegend":true,"textposition":"auto","x":["Python"],"xaxis":"x","y":[4655],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Statistics","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Statistics","offsetgroup":"Statistics","orientation":"v","showlegend":true,"textposition":"auto","x":["Statistics"],"xaxis":"x","y":[3959],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AI","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"AI","offsetgroup":"AI","orientation":"v","showlegend":true,"textposition":"auto","x":["AI"],"xaxis":"x","y":[3700],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Java","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Java","offsetgroup":"Java","orientation":"v","showlegend":true,"textposition":"auto","x":["Java"],"xaxis":"x","y":[2672],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Machine Learning","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Machine Learning","offsetgroup":"Machine Learning","orientation":"v","showlegend":true,"textposition":"auto","x":["Machine Learning"],"xaxis":"x","y":[2121],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Data Science","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Data Science","offsetgroup":"Data Science","orientation":"v","showlegend":true,"textposition":"auto","x":["Data Science"],"xaxis":"x","y":[1390],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003eFrequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Big Data","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Big Data","offsetgroup":"Big Data","orientation":"v","showlegend":true,"textposition":"auto","x":["Big Data"],"xaxis":"x","y":[1376],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9fde106c-015a-4428-ac1c-88de03255ad3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9fde106c-015a-4428-ac1c-88de03255ad3")) {                    Plotly.newPlot(                        "9fde106c-015a-4428-ac1c-88de03255ad3",                        [{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003ePercentage=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cloud","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Cloud","offsetgroup":"Cloud","orientation":"v","showlegend":true,"text":["7.31%"],"textposition":"outside","x":["Cloud"],"xaxis":"x","y":[7.308092919603711],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003ePercentage=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SQL","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"SQL","offsetgroup":"SQL","orientation":"v","showlegend":true,"text":["4.19%"],"textposition":"outside","x":["SQL"],"xaxis":"x","y":[4.193816663840645],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003ePercentage=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Python","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Python","offsetgroup":"Python","orientation":"v","showlegend":true,"text":["3.76%"],"textposition":"outside","x":["Python"],"xaxis":"x","y":[3.7586092741968042],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003ePercentage=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Statistics","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Statistics","offsetgroup":"Statistics","orientation":"v","showlegend":true,"text":["3.2%"],"textposition":"outside","x":["Statistics"],"xaxis":"x","y":[3.196634611502717],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003ePercentage=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AI","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"AI","offsetgroup":"AI","orientation":"v","showlegend":true,"text":["2.99%"],"textposition":"outside","x":["AI"],"xaxis":"x","y":[2.9875089827128196],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003ePercentage=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Java","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Java","offsetgroup":"Java","orientation":"v","showlegend":true,"text":["2.16%"],"textposition":"outside","x":["Java"],"xaxis":"x","y":[2.157465946434771],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003ePercentage=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Machine Learning","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Machine Learning","offsetgroup":"Machine Learning","orientation":"v","showlegend":true,"text":["1.71%"],"textposition":"outside","x":["Machine Learning"],"xaxis":"x","y":[1.712569338468619],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x}\u003cbr\u003ePercentage=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Data Science","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Data Science","offsetgroup":"Data Science","orientation":"v","showlegend":true,"text":["1.12%"],"textposition":"outside","x":["Data Science"],"xaxis":"x","y":[1.122334455667789],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skill=%{x ...

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# --- Subplots: Eurostat trend (left) + normalized skills snapshot (right) ---
fig_dash = make_subplots(
    rows=1, cols=2,
    subplot_titles=('Eurostat Digital Skills Trend (IE vs EU)', 'Job Posting Skill Demand (Normalized %)'),
    column_widths=[0.55, 0.45]
)

# Left: Eurostat line(s)
for col in pivot.columns:
    fig_dash.add_trace(
        go.Scatter(x=pivot.index, y=pivot[col], mode='lines+markers', name=col),
        row=1, col=1
    )
fig_dash.update_xaxes(title_text='Year', row=1, col=1)
fig_dash.update_yaxes(title_text='% with basic/above basic digital skills', row=1, col=1)

# Right: Normalized skills bar
fig_dash.add_trace(
    go.Bar(x=skill_df['Skill'], y=skill_df['Percentage'], name='Skills'),
    row=1, col=2
)
fig_dash.update_yaxes(title_text='Share of postings (%)', row=1, col=2)

fig_dash.update_layout(
    title_text='Digital Skills vs Industry Demand',
    showlegend=True,
    bargap=0.25
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cc047c92-074f-42e4-8ba6-9f3c2a6a6bba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc047c92-074f-42e4-8ba6-9f3c2a6a6bba")) {                    Plotly.newPlot(                        "cc047c92-074f-42e4-8ba6-9f3c2a6a6bba",                        [{"mode":"lines+markers","name":"EU27_2020","x":[2015,2016,2017,2019,2021,2023],"y":[null,null,null,null,53.93333333333334,55.57],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"lines+markers","name":"IE","x":[2015,2016,2017,2019,2021,2023],"y":[44.38,44.19,47.64,53.38,70.49666666666667,72.93],"type":"scatter","xaxis":"x","yaxis":"y"},{"name":"Skills","x":["Cloud","SQL","Python","Statistics","AI","Java","Machine Learning","Data Science","Big Data"],"y":[7.308092919603711,4.193816663840645,3.7586092741968042,3.196634611502717,2.9875089827128196,2.157465946434771,1.712569338468619,1.122334455667789,1.1110303676250919],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth ...

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(rows=1, cols=2, subplot_titles=('Eurostat Digital Skills Trend', 'Job Posting Skill Demand'))

# Left: Eurostat trend
fig.add_trace(go.Scatter(x=pivot.index, y=pivot['IE'], mode='lines+markers', name='Ireland'), row=1, col=1)
fig.add_trace(go.Scatter(x=pivot.index, y=pivot['EU27_2020'], mode='lines+markers', name='EU'), row=1, col=1)

# Right: Horizontal bars for job postings
sorted_skills = skill_df.sort_values('Percentage', ascending=True)
fig.add_trace(go.Bar(x=sorted_skills['Percentage'], y=sorted_skills['Skill'], orientation='h', name='Skills'), row=1, col=2)

fig.update_layout(title_text='Digital Skills vs Industry Demand', height=600)
fig.update_xaxes(title_text='Year', row=1, col=1)
fig.update_yaxes(title_text='% Digital Skills', row=1, col=1)
fig.update_xaxes(title_text='Share of postings (%)', row=1, col=2)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e3693a78-0549-4782-a3f1-96d6d681b85d" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e3693a78-0549-4782-a3f1-96d6d681b85d")) {                    Plotly.newPlot(                        "e3693a78-0549-4782-a3f1-96d6d681b85d",                        [{"mode":"lines+markers","name":"Ireland","x":[2015,2016,2017,2019,2021,2023],"y":[44.38,44.19,47.64,53.38,70.49666666666667,72.93],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"lines+markers","name":"EU","x":[2015,2016,2017,2019,2021,2023],"y":[null,null,null,null,53.93333333333334,55.57],"type":"scatter","xaxis":"x","yaxis":"y"},{"name":"Skills","orientation":"h","x":[1.1110303676250919,1.122334455667789,1.712569338468619,2.157465946434771,2.9875089827128196,3.196634611502717,3.7586092741968042,4.193816663840645,7.308092919603711],"y":["Big Data","Data Science","Machine Learning","Java","AI","Statistics","Python","SQL","Cloud"],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar ...

# %%
#include in meeting

import plotly.express as px

fig_eurostat = px.line(pivot.reset_index(), x='TIME_PERIOD', y=pivot.columns,
                       markers=True,
                       title='Eurostat Digital Skills Trend: Ireland vs EU',
                       labels={'value':'% Digital Skills','TIME_PERIOD':'Year'},
                       color_discrete_map={'IE':'blue','EU27_2020':'red'})
fig_eurostat.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cb9448f1-65f0-4b0e-a718-b4f4367f62a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb9448f1-65f0-4b0e-a718-b4f4367f62a4")) {                    Plotly.newPlot(                        "cb9448f1-65f0-4b0e-a718-b4f4367f62a4",                        [{"hovertemplate":"variable=EU27_2020\u003cbr\u003eYear=%{x}\u003cbr\u003e% Digital Skills=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"EU27_2020","line":{"color":"red","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"EU27_2020","orientation":"v","showlegend":true,"x":[2015,2016,2017,2019,2021,2023],"xaxis":"x","y":[null,null,null,null,53.93333333333334,55.57],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=IE\u003cbr\u003eYear=%{x}\u003cbr\u003e% Digital Skills=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"IE","line":{"color":"blue","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"IE","orientation":"v","showlegend":true,"x":[2015,2016,2017,2019,2021,2023],"xaxis":"x","y":[44.38,44.19,47.64,53.38,70.49666666666667,72.93],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity" ...

# %%
sorted_skills = skill_df.sort_values('Percentage', ascending=True)

fig_skills = px.bar(sorted_skills, x='Percentage', y='Skill', orientation='h',
                    title='Job Posting Skill Demand (Normalized %)',
                    labels={'Percentage':'Share of postings (%)'})
fig_skills.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e8d41320-619e-40c8-b889-fdaae41c90b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8d41320-619e-40c8-b889-fdaae41c90b1")) {                    Plotly.newPlot(                        "e8d41320-619e-40c8-b889-fdaae41c90b1",                        [{"alignmentgroup":"True","hovertemplate":"Share of postings (%)=%{x}\u003cbr\u003eSkill=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[1.1110303676250919,1.122334455667789,1.712569338468619,2.157465946434771,2.9875089827128196,3.196634611502717,3.7586092741968042,4.193816663840645,7.308092919603711],"xaxis":"x","y":["Big Data","Data Science","Machine Learning","Java","AI","Statistics","Python","SQL","Cloud"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{" ...

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig_dashboard = make_subplots(rows=1, cols=2, subplot_titles=('Eurostat Digital Skills Trend', 'Job Posting Skill Demand'))

# Left: Eurostat trend
fig_dashboard.add_trace(go.Scatter(x=pivot.index, y=pivot['IE'], mode='lines+markers', name='Ireland'), row=1, col=1)
fig_dashboard.add_trace(go.Scatter(x=pivot.index, y=pivot['EU27_2020'], mode='lines+markers', name='EU'), row=1, col=1)

# Right: Horizontal bars for job postings
fig_dashboard.add_trace(go.Bar(x=sorted_skills['Percentage'], y=sorted_skills['Skill'], orientation='h', name='Skills'), row=1, col=2)

fig_dashboard.update_layout(title_text='Digital Skills vs Industry Demand', height=600)
fig_dashboard.update_xaxes(title_text='Year', row=1, col=1)
fig_dashboard.update_yaxes(title_text='% Digital Skills', row=1, col=1)
fig_dashboard.update_xaxes(title_text='Share of postings (%)', row=1, col=2)

fig_dashboard.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c4d6fe61-6240-4872-9713-433680e8ad23" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c4d6fe61-6240-4872-9713-433680e8ad23")) {                    Plotly.newPlot(                        "c4d6fe61-6240-4872-9713-433680e8ad23",                        [{"mode":"lines+markers","name":"Ireland","x":[2015,2016,2017,2019,2021,2023],"y":[44.38,44.19,47.64,53.38,70.49666666666667,72.93],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"lines+markers","name":"EU","x":[2015,2016,2017,2019,2021,2023],"y":[null,null,null,null,53.93333333333334,55.57],"type":"scatter","xaxis":"x","yaxis":"y"},{"name":"Skills","orientation":"h","x":[1.1110303676250919,1.122334455667789,1.712569338468619,2.157465946434771,2.9875089827128196,3.196634611502717,3.7586092741968042,4.193816663840645,7.308092919603711],"y":["Big Data","Data Science","Machine Learning","Java","AI","Statistics","Python","SQL","Cloud"],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar ...
